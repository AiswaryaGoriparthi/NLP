# %% [markdown]
# <a href="https://colab.research.google.com/github/AiswaryaGoriparthi/NLP/blob/main/Tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
corpus="""Hello Welcome, to Aiswarya's NLP Tutorials.
 I want to become NLP Engineer!
Please do watch the entire course to become expert in NLP.
"""

# %%
print(corpus)
# Out:
# Hello Welcome, to Aiswarya's NLP Tutorials.
#  I want to become NLP Engineer!
# Please do watch the entire course to become expert in NLP.

# %%
#paragraph to sentence
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)
documents
# Out:
# ["Hello Welcome, to Aiswarya's NLP Tutorials.",
#  'I want to become NLP Engineer!',
#  'Please do watch the entire course to become expert in NLP.']

# %%
type(documents)
# Out:
# list

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
for sentence in documents:
  print(sentence)
# Out:
# Hello Welcome, to Aiswarya's NLP Tutorials.
# I want to become NLP Engineer!
# Please do watch the entire course to become expert in NLP.

# %%
#paragraph to words
#sentence to words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Aiswarya',
#  "'s",
#  'NLP',
#  'Tutorials',
#  '.',
#  'I',
#  'want',
#  'to',
#  'become',
#  'NLP',
#  'Engineer',
#  '!',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
#TreebankWordTokenizer
from nltk.tokenize import TreebankWordTokenizer
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Aiswarya',
#  "'s",
#  'NLP',
#  'Tutorials.',
#  'I',
#  'want',
#  'to',
#  'become',
#  'NLP',
#  'Engineer',
#  '!',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
