# %% [markdown]
# <a href="https://colab.research.google.com/github/AiswaryaGoriparthi/NLP/blob/main/Lemmatization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer=WordNetLemmatizer()

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
lemmatizer.lemmatize("going")
# Out:
# 'going'

# %%
lemmatizer.lemmatize("going",pos='v')
# Out:
# 'go'

# %%
lemmatizer.lemmatize("going",pos='a')
# Out:
# 'going'

# %%
words=["eating","eat","eaten","going","goes","gone","running","runs"]

# %%
for word in words:
  print(word+"----->"+lemmatizer.lemmatize(word))
# Out:
# eating----->eating
# eat----->eat
# eaten----->eaten
# going----->going
# goes----->go
# gone----->gone
# running----->running
# runs----->run

# %%
for word in words:
  print(word+"----->"+lemmatizer.lemmatize(word,pos='v'))
# Out:
# eating----->eat
# eat----->eat
# eaten----->eat
# going----->go
# goes----->go
# gone----->go
# running----->run
# runs----->run
